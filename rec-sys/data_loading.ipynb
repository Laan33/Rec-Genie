# %%
# Use credentials in credentials.py to connect to the api
import credentials
# import requests
# import json
# import pandas as pd

import tmdbsimple as tmdb
tmdb.API_KEY = credentials.tmdb_api_key
tmdb.REQUESTS_TIMEOUT = (2, 5)  # seconds, for connect and read specifically 

movie = tmdb.Movies(603)
response = movie.info()
movie.title
# Out:
# 'The Matrix'
